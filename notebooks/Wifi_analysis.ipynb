# %%
# 1. Imports and Configurations
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

warnings.filterwarnings("ignore")
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)
custom_palette = ['#09122C', '#872341', '#BE3144', '#E17564']

# %%
# 2. Function: Save Data to CSV
def save_signal_data(data, index_values, level_tag="L"):
    for wing in data['wifi']:
        df_wing = pd.DataFrame({
            'wifi': data['wifi'][wing],
            'mobile_net': data['mobile_net'][wing]
        }, index=index_values[wing])

        filename = f"{level_tag}_{wing}_signal_strength.csv"
        df_wing.to_csv(filename, index=True)
        print(f"✅ Saved: {filename}")

# %%
# 3. Level 3 Dataset
level3_data = {
    'wifi': {
        'a': [80, 76, 61, 48, 62],
        'b': [89, 62, 50, 73, 82, 58, 61],
        'c': [89, 91, 93, 114, 72, 80],
        'd': [85, 89, 91, 100, 81, 74],
        'e': [73, 46, 75, 66, 70, 60, 74, 66, 49, 79, 64, 57],
        'f': [62, 61, 65, 59],
        'g': [60, 91, 42, 86, 73, 81, 77, 50, 38, 56],
        'h': [68, 65],
    },
    'mobile_net': {
        'a': [120, 109, 103, 123, 119],
        'b': [115, 117, 128, 126, 123, 131, 131],
        'c': [103, 101, 115, 111, 103, 107],
        'd': [99, 97, 105, 118, 109, 104],
        'e': [105, 104, 102, 111, 102, 110, 120, 106, 116, 112, 111, 108],
        'f': [104, 114, 110, 114],
        'g': [103, 116, 112, 109, 120, 121, 119, 106, 115, 106],
        'h': [112, 114],
    }
}
index_values = {
    'a': ['Point 1', 'Point 2', 'Point 3', 'Point 4', 'Point 5'],
    'b': ['Point 1', 'Point 2', 'Point 3', 'Point 4', 'Point 5', 'Point 6', 'Point 7'],
    'c': ['Point 1', 'Point 2', 'Point 3', 'Point 4', 'Point 5', 'Point 6'],
    'd': ['Point 1', 'Point 2', 'Point 3', 'Point 4', 'Point 5', 'Point 6'],
    'e': ['Point 1', 'Point 2', 'Point 3', 'Point 4', 'Point 5', 'Point 6', 'Point 7',
          'Point 8', 'Point 9', 'Point 10', 'Point 11', 'Point 12'],
    'f': ['Point 1', 'Point 2', 'Point 3', 'Point 4'],
    'g': ['Point 1', 'Point 2', 'Point 3', 'Point 4', 'Point 5', 'Point 6', 'Point 7',
          'Point 8', 'Point 9', 'Point 10'],
    'h': ['Point 1', 'Point 2'],
}

save_signal_data(level3_data, index_values, level_tag="L3")
# Out:
# ✅ Saved: L3_a_signal_strength.csv
# ✅ Saved: L3_b_signal_strength.csv
# ✅ Saved: L3_c_signal_strength.csv
# ✅ Saved: L3_d_signal_strength.csv
# ✅ Saved: L3_e_signal_strength.csv
# ✅ Saved: L3_f_signal_strength.csv
# ✅ Saved: L3_g_signal_strength.csv
# ✅ Saved: L3_h_signal_strength.csv

# %%
# 4. Level 4 Dataset
level4_data = {
    'wifi': {
        'a': [78, 74, 63, 47, 61],
        'b': [87, 61, 48, 72, 81, 56, 60],
        'c': [88, 90, 92, 113, 71, 79],
        'd': [85, 89, 91, 100, 81, 74],
        'e': [74, 47, 76, 67, 71, 61, 75, 67, 50, 80, 65, 58],
        'f': [60, 59, 64, 58],
        'g': [58, 90, 41, 85, 72, 80, 76, 49, 37, 55],
        'h': [66, 63],
    },
    'mobile_net': {
        'a': [118, 107, 101, 121, 117],
        'b': [113, 115, 126, 124, 121, 129, 130],
        'c': [102, 99, 113, 109, 101, 105],
        'd': [99, 97, 105, 118, 109, 104],
        'e': [107, 105, 103, 113, 104, 112, 122, 108, 118, 113, 112, 109],
        'f': [102, 112, 108, 112],
        'g': [101, 113, 109, 106, 118, 119, 117, 104, 113, 104],
        'h': [110, 112],
    }
}
save_signal_data(level4_data, index_values, level_tag="L4")
# Out:
# ✅ Saved: L4_a_signal_strength.csv
# ✅ Saved: L4_b_signal_strength.csv
# ✅ Saved: L4_c_signal_strength.csv
# ✅ Saved: L4_d_signal_strength.csv
# ✅ Saved: L4_e_signal_strength.csv
# ✅ Saved: L4_f_signal_strength.csv
# ✅ Saved: L4_g_signal_strength.csv
# ✅ Saved: L4_h_signal_strength.csv

# %%
# 5. Load DataFrames from CSV
def load_wing_data(level_tag="L4", wings=['a','b','c','d','e','f','g','h']):
    df_dict = {}
    for wing in wings:
        filename = f"/content/Dataset/{level_tag}/{level_tag}_{wing}_signal_strength.csv"
        if os.path.exists(filename):
            df_dict[wing] = pd.read_csv(filename, index_col=0)
            print(f"📂 Loaded: {filename}")
        else:
            print(f"❌ File not found: {filename}")
    return df_dict

# %%
# Load Level 4 data
df = load_wing_data("L4")
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
# 6. Visualization Function
def plot_signal_comparison(df_dict, wing):
    if wing not in df_dict:
        print(f"⚠️ Wing '{wing}' not found.")
        return
    data = df_dict[wing]
    data.plot(kind='bar', color=['#1f77b4', '#ff7f0e'])
    plt.title(f"Signal Strength Comparison - Wing {wing.upper()}")
    plt.ylabel("Signal Strength (dBm)")
    plt.xlabel("Measurement")
    plt.xticks(rotation=45)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %%
# Example plot
plot_signal_comparison(df, 'e')

# %%
import plotly.graph_objects as go
import plotly.subplots as sp

# Load Level 4 data
df = load_wing_data("L4")

# Define wings list
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']

# Create a Plotly subplot figure (rows = number of wings)
fig = sp.make_subplots(
    rows=len(wings), cols=1, shared_xaxes=True,
    subplot_titles=[f"Wing {wing.upper()}" for wing in wings]
)

# Loop through each wing to create a bar chart
for i, wing in enumerate(wings):
    wifi_signal = df[wing]['wifi']
    mobile_signal = df[wing]['mobile_net']

    # Create bar traces for Wi-Fi and Mobile Network signal strength
    trace_wifi = go.Bar(
        x=df[wing].index, y=wifi_signal, name="Wi-Fi",
        marker=dict(color='#BE3144'),
        hoverinfo='x+y+name',
    )

    trace_mobile = go.Bar(
        x=df[wing].index, y=mobile_signal, name="Mobile Network",
        marker=dict(color='#E17564'),
        hoverinfo='x+y+name',
    )

    # Add traces to the subplot
    fig.add_trace(trace_wifi, row=i+1, col=1)
    fig.add_trace(trace_mobile, row=i+1, col=1)

# Update layout for the figure
fig.update_layout(
    title="Signal Strength Comparison: Wi-Fi vs Mobile Network",
    height=600 * len(wings),
    xaxis_title="Measurement Point",
    yaxis_title="Signal Strength (dBm)",
    barmode='group',
    showlegend=True,
    legend=dict(x=0.8, y=1),
    # plot_bgcolor='#222222',  # Dark background for better contrast
    # paper_bgcolor='#222222',  # Dark background for paper as well
    # font=dict(color='white'),
    # hovermode="x unified",  # Hover mode for all traces
)

# Show the interactive plot
fig.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
import plotly.subplots as sp

# Load Level 3 data
df = load_wing_data("L3")

# Define wings list
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']

# Create a Plotly subplot figure (rows = number of wings)
fig = sp.make_subplots(
    rows=len(wings), cols=1, shared_xaxes=True,
    subplot_titles=[f"Wing {wing.upper()}" for wing in wings]
)

# Loop through each wing to create a bar chart
for i, wing in enumerate(wings):
    wifi_signal = df[wing]['wifi']
    mobile_signal = df[wing]['mobile_net']

    # Create bar traces for Wi-Fi and Mobile Network signal strength
    trace_wifi = go.Bar(
        x=df[wing].index, y=wifi_signal, name="Wi-Fi",
        marker=dict(color='#BE3144'),
        hoverinfo='x+y+name',
    )

    trace_mobile = go.Bar(
        x=df[wing].index, y=mobile_signal, name="Mobile Network",
        marker=dict(color='#E17564'),
        hoverinfo='x+y+name',
    )

    # Add traces to the subplot
    fig.add_trace(trace_wifi, row=i+1, col=1)
    fig.add_trace(trace_mobile, row=i+1, col=1)

# Update layout for the figure
fig.update_layout(
    title="Signal Strength Comparison: Wi-Fi vs Mobile Network",
    height=600 * len(wings),
    xaxis_title="Measurement Point",
    yaxis_title="Signal Strength (dBm)",
    barmode='group',
    showlegend=True,
    legend=dict(x=0.8, y=1),
    # plot_bgcolor='#222222',  # Dark background for better contrast
    # paper_bgcolor='#222222',  # Dark background for paper as well
    # font=dict(color='white'),
    # hovermode="x unified",  # Hover mode for all traces
)

# Show the interactive plot
fig.show()
# Out:
# ❌ File not found: /content/Dataset/L3/L3_a_signal_strength.csv
# ❌ File not found: /content/Dataset/L3/L3_b_signal_strength.csv
# ❌ File not found: /content/Dataset/L3/L3_c_signal_strength.csv
# ❌ File not found: /content/Dataset/L3/L3_d_signal_strength.csv
# ❌ File not found: /content/Dataset/L3/L3_e_signal_strength.csv
# ❌ File not found: /content/Dataset/L3/L3_f_signal_strength.csv
# ❌ File not found: /content/Dataset/L3/L3_g_signal_strength.csv
# ❌ File not found: /content/Dataset/L3/L3_h_signal_strength.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-902f312803cc> in <cell line: 0>()
#      16 # Loop through each wing to create a bar chart
#      17 for i, wing in enumerate(wings):
# ---> 18     wifi_signal = df[wing]['wifi']
#      19     mobile_signal = df[wing]['mobile_net']
#      20
#
# KeyError: 'e'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Level 3 data
df = load_wing_data("L3")


# Calculate the average signal strength for Wi-Fi and Mobile Network for each wing
avg_wifi = {wing: df[wing]['wifi'].mean() for wing in df}
avg_mobile_net = {wing: df[wing]['mobile_net'].mean() for wing in df}

# Convert the averages to a DataFrame for easier plotting
avg_df = pd.DataFrame({
    'Wi-Fi': avg_wifi,
    'Mobile Network': avg_mobile_net
}).T

# Plot the average signal strengths
plt.figure(figsize=(12, 7))

# Use a distinct color for Wi-Fi and Mobile Network without using a palette
avg_df.plot(kind='bar', color=['#BE3144', '#E17564'], edgecolor='white', width=0.8, linewidth=1.5)

# Title and labels
plt.title('Average Wi-Fi vs Mobile Network Signal Strength Across Wings', fontsize=20, color='white', pad=20)
plt.ylabel('Average Signal Strength (dBm)', fontsize=16, color='white', labelpad=10)
plt.xlabel('Wing', fontsize=16, color='white', labelpad=10)
plt.xticks(rotation=45, fontsize=14, color='white', ha='right')
plt.yticks(fontsize=14, color='white')

# Adjust gridlines for readability and set background color
plt.grid(True, linestyle='--', color='white', alpha=0.1)
plt.gca().set_facecolor('#2E2E2E')  # Darker background color for the plot
plt.gcf().set_facecolor('#222222')  # Dark background for the whole figure

# Adjust legend with improved appearance
plt.legend(
    loc='upper left',
    fontsize=14,
    title='Signal Type',
    title_fontsize=16,
    facecolor='#3E3E3E',
    edgecolor='white',
    framealpha=0.7,
    labelspacing=1.2,
    labels=['Wi-Fi', 'Mobile Network']
)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Level 4 data
df = load_wing_data("L4")

# Calculate the average signal strength for Wi-Fi and Mobile Network for each wing
avg_wifi = {wing: df[wing]['wifi'].mean() for wing in df}
avg_mobile_net = {wing: df[wing]['mobile_net'].mean() for wing in df}

# Convert the averages to a DataFrame for easier plotting
avg_df = pd.DataFrame({
    'Wi-Fi': avg_wifi,
    'Mobile Network': avg_mobile_net
}).T

# Plot the average signal strengths
plt.figure(figsize=(12, 7))

# Create the bar plot with a nicer color scheme and bar spacing
avg_df.plot(kind='bar', color=['#BE3144', '#E17564'], edgecolor='white', width=0.8, linewidth=1.5)

# Title and labels
plt.title('Average Wi-Fi vs Mobile Network Signal Strength Across Wings', fontsize=20, color='white', pad=20)
plt.ylabel('Average Signal Strength (dBm)', fontsize=16, color='white', labelpad=10)
plt.xlabel('Wing', fontsize=16, color='white', labelpad=10)
plt.xticks(rotation=45, fontsize=14, color='white', ha='right')
plt.yticks(fontsize=14, color='white')

# Adjust gridlines for readability and set background color
plt.grid(True, linestyle='--', color='white', alpha=0.1)
plt.gca().set_facecolor('#2E2E2E')  # Darker background color for the plot
plt.gcf().set_facecolor('#222222')  # Dark background for the whole figure

# Adjust legend with improved appearance
plt.legend(
    loc='upper left',
    fontsize=14,
    title='Signal Type',
    title_fontsize=16,
    facecolor='#3E3E3E',
    edgecolor='white',
    framealpha=0.7,
    labelspacing=1.2,
    labels=['Wi-Fi', 'Mobile Network']
)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Load Level 3 data
df = load_wing_data("L3")
# Calculate the difference between Wi-Fi and Mobile Network Signal Strength
wifi_vs_mobile_diff = {wing: df[wing]['wifi'] - df[wing]['mobile_net'] for wing in df}
diff_df = pd.DataFrame(wifi_vs_mobile_diff)

# Plot the difference values
diff_df.plot(kind='bar', figsize=(10, 6), color=['#BE3144', '#E17564'], edgecolor='white', linewidth=1.5)
plt.title('Difference Between Wi-Fi and Mobile Network Signal Strength', fontsize=18, color='white')
plt.ylabel('Difference (dBm)', fontsize=14, color='white')
plt.xlabel('Measurement', fontsize=14, color='white')
plt.xticks(rotation=45, fontsize=12, color='white')
plt.tight_layout()

# Adjust the legend
plt.legend(loc='best', fontsize=12, facecolor='#872341', edgecolor='#BE3144', framealpha=0.7)

plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Load Level 4 data
df = load_wing_data("L4")
# Calculate the difference between Wi-Fi and Mobile Network Signal Strength
wifi_vs_mobile_diff = {wing: df[wing]['wifi'] - df[wing]['mobile_net'] for wing in df}
diff_df = pd.DataFrame(wifi_vs_mobile_diff)

# Plot the difference values
diff_df.plot(kind='bar', figsize=(10, 6), color=['#BE3144', '#E17564'], edgecolor='white', linewidth=1.5)
plt.title('Difference Between Wi-Fi and Mobile Network Signal Strength', fontsize=18, color='white')
plt.ylabel('Difference (dBm)', fontsize=14, color='white')
plt.xlabel('Measurement', fontsize=14, color='white')
plt.xticks(rotation=45, fontsize=12, color='white')
plt.tight_layout()

# Adjust the legend
plt.legend(loc='best', fontsize=12, facecolor='#872341', edgecolor='#BE3144', framealpha=0.7)

plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Load Level 3 data
df = load_wing_data("L3")
# Combine data for violin plot
violin_data = {
    'wifi': [],
    'mobile_net': [],
    'wing': []
}

# Flatten the data for each wing
for wing in df:
    wifi_values = df[wing]['wifi']
    mobile_net_values = df[wing]['mobile_net']

    # Append data for this wing
    violin_data['wifi'].extend(wifi_values)
    violin_data['mobile_net'].extend(mobile_net_values)
    violin_data['wing'].extend([wing] * len(wifi_values))  # Repeat the wing label for each measurement

# Create a DataFrame for plotting
violin_df = pd.DataFrame(violin_data)

# Create the violin plot
plt.figure(figsize=(12, 6))
sns.violinplot(x='wing', y='wifi', data=violin_df, color='#BE3144', inner="quart", linewidth=1.2)
sns.violinplot(x='wing', y='mobile_net', data=violin_df, color='#E17564', inner="quart", linewidth=1.2)

# Apply custom title and labels with improved contrast
plt.title('Distribution of Wi-Fi and Mobile Network Signal Strength Across Wings', fontsize=16, color='white')
plt.xlabel('Wing', fontsize=14, color='white')
plt.ylabel('Signal Strength', fontsize=14, color='white')

# Improve layout and visibility
plt.tight_layout()

# Set a better style for the legend
plt.legend(title="Signal Type", fontsize=12, loc='best', facecolor='white', edgecolor='black', framealpha=0.7)

plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Load Level 4 data
df = load_wing_data("L4")
# Combine data for violin plot
violin_data = {
    'wifi': [],
    'mobile_net': [],
    'wing': []
}

# Flatten the data for each wing
for wing in df:
    wifi_values = df[wing]['wifi']
    mobile_net_values = df[wing]['mobile_net']

    # Append data for this wing
    violin_data['wifi'].extend(wifi_values)
    violin_data['mobile_net'].extend(mobile_net_values)
    violin_data['wing'].extend([wing] * len(wifi_values))  # Repeat the wing label for each measurement

# Create a DataFrame for plotting
violin_df = pd.DataFrame(violin_data)

# Create the violin plot
plt.figure(figsize=(12, 6))
sns.violinplot(x='wing', y='wifi', data=violin_df, color='#BE3144', inner="quart", linewidth=1.2)
sns.violinplot(x='wing', y='mobile_net', data=violin_df, color='#E17564', inner="quart", linewidth=1.2)

# Apply custom title and labels with improved contrast
plt.title('Distribution of Wi-Fi and Mobile Network Signal Strength Across Wings', fontsize=16, color='white')
plt.xlabel('Wing', fontsize=14, color='white')
plt.ylabel('Signal Strength', fontsize=14, color='white')

# Improve layout and visibility
plt.tight_layout()

# Set a better style for the legend
plt.legend(title="Signal Type", fontsize=12, loc='best', facecolor='white', edgecolor='black', framealpha=0.7)

plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt

# List of wings to plot
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']
# Load Level 3 data
df = load_wing_data("L3")
# Line plot to observe trends in signal strength for each wing
plt.figure(figsize=(12, 6))

# Iterate through each wing to plot Wi-Fi and Mobile Network data
for wing in wings:
    wifi_signal = df[wing]['wifi']  # Wi-Fi signal strength
    mobile_net_signal = df[wing]['mobile_net']  # Mobile network signal strength

    # Plot Wi-Fi signal strength
    plt.plot(wifi_signal.index, wifi_signal, marker='o', color='#BE3144', linewidth=2, label=f'Wi-Fi - Wing {wing.upper()}')

    # Plot Mobile Network signal strength
    plt.plot(mobile_net_signal.index, mobile_net_signal, marker='x', color='#E17564', linewidth=2, label=f'Mobile Network - Wing {wing.upper()}')

# Add titles and labels
plt.title('Wi-Fi and Mobile Network Signal Strength Trends Across Wings', fontsize=16, color='white')
plt.xlabel('Measurement', fontsize=14, color='white')
plt.ylabel('Signal Strength', fontsize=14, color='white')
plt.xticks(rotation=45, fontsize=12, color='white')

# Adjust legend to avoid repetition (only showing one entry for each signal type per wing)
plt.legend(loc='best', fontsize=12, facecolor='white', edgecolor='black', framealpha=0.7, labelspacing=1.2)

# Tight layout to ensure everything fits
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt

# List of wings to plot
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']
# Load Level 4 data
df = load_wing_data("L4")
# Line plot to observe trends in signal strength for each wing
plt.figure(figsize=(12, 6))

# Iterate through each wing to plot Wi-Fi and Mobile Network data
for wing in wings:
    wifi_signal = df[wing]['wifi']  # Wi-Fi signal strength
    mobile_net_signal = df[wing]['mobile_net']  # Mobile network signal strength

    # Plot Wi-Fi signal strength
    plt.plot(wifi_signal.index, wifi_signal, marker='o', color='#BE3144', linewidth=2, label=f'Wi-Fi - Wing {wing.upper()}')

    # Plot Mobile Network signal strength
    plt.plot(mobile_net_signal.index, mobile_net_signal, marker='x', color='#E17564', linewidth=2, label=f'Mobile Network - Wing {wing.upper()}')

# Add titles and labels
plt.title('Wi-Fi and Mobile Network Signal Strength Trends Across Wings', fontsize=16, color='white')
plt.xlabel('Measurement', fontsize=14, color='white')
plt.ylabel('Signal Strength', fontsize=14, color='white')
plt.xticks(rotation=45, fontsize=12, color='white')

# Adjust legend to avoid repetition (only showing one entry for each signal type per wing)
plt.legend(loc='best', fontsize=12, facecolor='white', edgecolor='black', framealpha=0.7, labelspacing=1.2)

# Tight layout to ensure everything fits
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of wings to plot
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']
# Load Level 3 data
df = load_wing_data("L3")
# Plot histograms for Wi-Fi and Mobile Network Signal Strength for each wing
plt.figure(figsize=(14, 8))

# Plot histogram for Wi-Fi signal strength
plt.subplot(2, 1, 1)
for wing in wings:
    sns.histplot(df[wing]['wifi'], label=f'Wi-Fi - Wing {wing.upper()}', kde=True, bins=10)
plt.title('Histogram of Wi-Fi Signal Strength Across Wings', fontsize=16)
plt.xlabel('Signal Strength', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.legend(loc='best', fontsize=10)

# Plot histogram for Mobile Network signal strength
plt.subplot(2, 1, 2)
for wing in wings:
    sns.histplot(df[wing]['mobile_net'], label=f'Mobile Network - Wing {wing.upper()}', kde=True, bins=10)
plt.title('Histogram of Mobile Network Signal Strength Across Wings', fontsize=16)
plt.xlabel('Signal Strength', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.legend(loc='best', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of wings to plot
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']
# Load Level 4 data
df = load_wing_data("L4")
# Plot histograms for Wi-Fi and Mobile Network Signal Strength for each wing
plt.figure(figsize=(14, 8))

# Plot histogram for Wi-Fi signal strength
plt.subplot(2, 1, 1)
for wing in wings:
    sns.histplot(df[wing]['wifi'], label=f'Wi-Fi - Wing {wing.upper()}', kde=True, bins=10)
plt.title('Histogram of Wi-Fi Signal Strength Across Wings', fontsize=16)
plt.xlabel('Signal Strength', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.legend(loc='best', fontsize=10)

# Plot histogram for Mobile Network signal strength
plt.subplot(2, 1, 2)
for wing in wings:
    sns.histplot(df[wing]['mobile_net'], label=f'Mobile Network - Wing {wing.upper()}', kde=True, bins=10)
plt.title('Histogram of Mobile Network Signal Strength Across Wings', fontsize=16)
plt.xlabel('Signal Strength', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.legend(loc='best', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Define wings list
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']
# Load Level 3 data
df = load_wing_data("L3")
# Initialize lists to store the data
wifi_values = []
mobile_net_values = []
wing_labels = []

# Combine data for each wing
for wing in wings:
    wifi_values.extend(df[wing]['wifi'])
    mobile_net_values.extend(df[wing]['mobile_net'])
    wing_labels.extend([wing] * len(df[wing]))

# Create a DataFrame for the pairplot
pairplot_df = pd.DataFrame({
    'wifi': wifi_values,
    'mobile_net': mobile_net_values,
    'wing': wing_labels
})

# Create a pairplot using seaborn
sns.pairplot(pairplot_df, hue='wing', palette='Set2', markers=['o', 's', 'D', '^', 'v', 'P', 'H'])

# Title for the plot
plt.suptitle('Pair Plot of Wi-Fi and Mobile Network Signal Strength Across Wings', y=1.02, fontsize=16)

# Adjust layout to make it fit better
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Define wings list
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']
# Load Level 4 data
df = load_wing_data("L4")
# Initialize lists to store the data
wifi_values = []
mobile_net_values = []
wing_labels = []

# Combine data for each wing
for wing in wings:
    wifi_values.extend(df[wing]['wifi'])
    mobile_net_values.extend(df[wing]['mobile_net'])
    wing_labels.extend([wing] * len(df[wing]))

# Create a DataFrame for the pairplot
pairplot_df = pd.DataFrame({
    'wifi': wifi_values,
    'mobile_net': mobile_net_values,
    'wing': wing_labels
})

# Create a pairplot using seaborn
sns.pairplot(pairplot_df, hue='wing', palette='Set2', markers=['o', 's', 'D', '^', 'v', 'P', 'H'])

# Title for the plot
plt.suptitle('Pair Plot of Wi-Fi and Mobile Network Signal Strength Across Wings', y=1.02, fontsize=16)

# Adjust layout to make it fit better
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define wings list
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']
# Load Level 3 data
df = load_wing_data("L3")
# Calculate the average signal strength for Wi-Fi and Mobile Network for each wing
avg_wifi = {wing: df[wing]['wifi'].mean() for wing in wings}
avg_mobile_net = {wing: df[wing]['mobile_net'].mean() for wing in wings}

# Prepare the data for the radar chart
avg_wifi_values = [avg_wifi[wing] for wing in wings]
avg_mobile_net_values = [avg_mobile_net[wing] for wing in wings]

# Create the angle for each axis
labels = wings
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()

# Make the radar chart
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Add the Wi-Fi data to the chart
ax.plot(angles, avg_wifi_values, color='skyblue', linewidth=2, linestyle='solid', label='Wi-Fi')
ax.fill(angles, avg_wifi_values, color='skyblue', alpha=0.25)

# Add the Mobile Network data to the chart
ax.plot(angles, avg_mobile_net_values, color='lightgreen', linewidth=2, linestyle='solid', label='Mobile Network')
ax.fill(angles, avg_mobile_net_values, color='lightgreen', alpha=0.25)

# Configure the plot
ax.set_yticklabels([])  # Remove radial labels
ax.set_xticks(angles)  # Set the angle labels
ax.set_xticklabels(labels)  # Set the wing names as labels
ax.set_title('Comparison of Wi-Fi and Mobile Network Signal Strengths Across Wings', fontsize=16)

# Show the legend
plt.legend(loc='best', fontsize=12)

# Tighten the layout and display the chart
plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define wings list
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']
# Load Level 4 data
df = load_wing_data("L4")
# Calculate the average signal strength for Wi-Fi and Mobile Network for each wing
avg_wifi = {wing: df[wing]['wifi'].mean() for wing in wings}
avg_mobile_net = {wing: df[wing]['mobile_net'].mean() for wing in wings}

# Prepare the data for the radar chart
avg_wifi_values = [avg_wifi[wing] for wing in wings]
avg_mobile_net_values = [avg_mobile_net[wing] for wing in wings]

# Create the angle for each axis
labels = wings
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()

# Make the radar chart
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Add the Wi-Fi data to the chart
ax.plot(angles, avg_wifi_values, color='skyblue', linewidth=2, linestyle='solid', label='Wi-Fi')
ax.fill(angles, avg_wifi_values, color='skyblue', alpha=0.25)

# Add the Mobile Network data to the chart
ax.plot(angles, avg_mobile_net_values, color='lightgreen', linewidth=2, linestyle='solid', label='Mobile Network')
ax.fill(angles, avg_mobile_net_values, color='lightgreen', alpha=0.25)

# Configure the plot
ax.set_yticklabels([])  # Remove radial labels
ax.set_xticks(angles)  # Set the angle labels
ax.set_xticklabels(labels)  # Set the wing names as labels
ax.set_title('Comparison of Wi-Fi and Mobile Network Signal Strengths Across Wings', fontsize=16)

# Show the legend
plt.legend(loc='best', fontsize=12)

# Tighten the layout and display the chart
plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt

# Define the wings
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']
# Load Level 3 data
df = load_wing_data("L3")
# Calculate the average Wi-Fi and Mobile Network signal strengths for each wing
wifi_signal_strength = [df[wing]['wifi'].mean() for wing in wings]
mobile_net_signal_strength = [df[wing]['mobile_net'].mean() for wing in wings]

# Plot the stacked bar chart
plt.figure(figsize=(12, 6))

# Plot the Wi-Fi signal strength
plt.bar(wings, wifi_signal_strength, label='Wi-Fi Signal Strength', color='skyblue')

# Plot the Mobile Network signal strength stacked on top of Wi-Fi
plt.bar(wings, mobile_net_signal_strength, bottom=wifi_signal_strength, label='Mobile Network Signal Strength', color='lightgreen')

# Add titles and labels
plt.title('Stacked Bar Plot of Wi-Fi and Mobile Network Signal Strengths Across Wings', fontsize=16)
plt.xlabel('Wing', fontsize=14)
plt.ylabel('Average Signal Strength', fontsize=14)

# Add legend
plt.legend(loc='upper left', fontsize=12)

# Tighten layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt

# Define the wings
wings = ['e', 'f', 'g', 'h', 'a', 'b', 'c', 'd']
# Load Level 4 data
df = load_wing_data("L4")
# Calculate the average Wi-Fi and Mobile Network signal strengths for each wing
wifi_signal_strength = [df[wing]['wifi'].mean() for wing in wings]
mobile_net_signal_strength = [df[wing]['mobile_net'].mean() for wing in wings]

# Plot the stacked bar chart
plt.figure(figsize=(12, 6))

# Plot the Wi-Fi signal strength
plt.bar(wings, wifi_signal_strength, label='Wi-Fi Signal Strength', color='skyblue')

# Plot the Mobile Network signal strength stacked on top of Wi-Fi
plt.bar(wings, mobile_net_signal_strength, bottom=wifi_signal_strength, label='Mobile Network Signal Strength', color='lightgreen')

# Add titles and labels
plt.title('Stacked Bar Plot of Wi-Fi and Mobile Network Signal Strengths Across Wings', fontsize=16)
plt.xlabel('Wing', fontsize=14)
plt.ylabel('Average Signal Strength', fontsize=14)

# Add legend
plt.legend(loc='upper left', fontsize=12)

# Tighten layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot density for Wi-Fi signal strength across wings
plt.figure(figsize=(12, 6))
# Load Level 3 data
df = load_wing_data("L3")
# Iterate over each wing in the dataset to plot the Wi-Fi signal strength
for wing in df:
    sns.kdeplot(df[wing]['wifi'], label=f'Wi-Fi - Wing {wing.upper()}', shade=True, alpha=0.5)

plt.title('Density Plot for Wi-Fi Signal Strengths Across Wings')
plt.xlabel('Signal Strength (dBm)')
plt.ylabel('Density')
plt.legend(loc='best', fontsize=10)
plt.tight_layout()
plt.show()

# Plot density for Mobile Network signal strength across wings
plt.figure(figsize=(12, 6))

# Iterate over each wing in the dataset to plot the Mobile Network signal strength
for wing in df:
    sns.kdeplot(df[wing]['mobile_net'], label=f'Mobile Network - Wing {wing.upper()}', shade=True, alpha=0.5)

plt.title('Density Plot for Mobile Network Signal Strengths Across Wings')
plt.xlabel('Signal Strength (dBm)')
plt.ylabel('Density')
plt.legend(loc='best', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot density for Wi-Fi signal strength across wings
plt.figure(figsize=(12, 6))
# Load Level 4 data
df = load_wing_data("L4")
# Iterate over each wing in the dataset to plot the Wi-Fi signal strength
for wing in df:
    sns.kdeplot(df[wing]['wifi'], label=f'Wi-Fi - Wing {wing.upper()}', shade=True, alpha=0.5)

plt.title('Density Plot for Wi-Fi Signal Strengths Across Wings')
plt.xlabel('Signal Strength (dBm)')
plt.ylabel('Density')
plt.legend(loc='best', fontsize=10)
plt.tight_layout()
plt.show()

# Plot density for Mobile Network signal strength across wings
plt.figure(figsize=(12, 6))

# Iterate over each wing in the dataset to plot the Mobile Network signal strength
for wing in df:
    sns.kdeplot(df[wing]['mobile_net'], label=f'Mobile Network - Wing {wing.upper()}', shade=True, alpha=0.5)

plt.title('Density Plot for Mobile Network Signal Strengths Across Wings')
plt.xlabel('Signal Strength (dBm)')
plt.ylabel('Density')
plt.legend(loc='best', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the wing labels and calculate average signal strengths for each wing
wing_labels = df.keys()  # Getting the wings directly from df keys
avg_wifi_values = [df[wing]['wifi'].mean() for wing in df]  # Average Wi-Fi signal for each wing
avg_mobile_net_values = [df[wing]['mobile_net'].mean() for wing in df]  # Average Mobile Network signal for each wing
# Load Level 3 data
df = load_wing_data("L3")
# Set up the x-axis positions
x = np.arange(len(wing_labels))  # The label locations

# Create a bar chart with two sets of bars (Wi-Fi vs Mobile Network)
width = 0.35  # The width of the bars
fig, ax = plt.subplots(figsize=(12, 6))
bars_wifi = ax.bar(x - width / 2, avg_wifi_values, width, label='Wi-Fi', color='skyblue')
bars_mobile_net = ax.bar(x + width / 2, avg_mobile_net_values, width, label='Mobile Network', color='lightgreen')

# Add labels, title, and custom x-axis tick labels
ax.set_xlabel('Wing')
ax.set_ylabel('Average Signal Strength (dBm)')
ax.set_title('Comparison of Average Wi-Fi and Mobile Network Signal Strengths Across Wings')
ax.set_xticks(x)
ax.set_xticklabels(wing_labels)
ax.legend()

# Function to add the value labels on top of the bars
def add_labels(bars):
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom')

add_labels(bars_wifi)
add_labels(bars_mobile_net)

plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the wing labels and calculate average signal strengths for each wing
wing_labels = df.keys()  # Getting the wings directly from df keys
avg_wifi_values = [df[wing]['wifi'].mean() for wing in df]  # Average Wi-Fi signal for each wing
avg_mobile_net_values = [df[wing]['mobile_net'].mean() for wing in df]  # Average Mobile Network signal for each wing
# Load Level 4 data
df = load_wing_data("L4")
# Set up the x-axis positions
x = np.arange(len(wing_labels))  # The label locations

# Create a bar chart with two sets of bars (Wi-Fi vs Mobile Network)
width = 0.35  # The width of the bars
fig, ax = plt.subplots(figsize=(12, 6))
bars_wifi = ax.bar(x - width / 2, avg_wifi_values, width, label='Wi-Fi', color='skyblue')
bars_mobile_net = ax.bar(x + width / 2, avg_mobile_net_values, width, label='Mobile Network', color='lightgreen')

# Add labels, title, and custom x-axis tick labels
ax.set_xlabel('Wing')
ax.set_ylabel('Average Signal Strength (dBm)')
ax.set_title('Comparison of Average Wi-Fi and Mobile Network Signal Strengths Across Wings')
ax.set_xticks(x)
ax.set_xticklabels(wing_labels)
ax.legend()

# Function to add the value labels on top of the bars
def add_labels(bars):
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom')

add_labels(bars_wifi)
add_labels(bars_mobile_net)

plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt

# Set up the figure for the bubble chart
plt.figure(figsize=(12, 6))
# Load Level 3 data
df = load_wing_data("L3")
# Loop through each wing to create a scatter plot for each Wi-Fi signal strength
for wing in df:
    # Bubble size is proportional to the Wi-Fi signal strength
    # Scale the size of the bubbles by multiplying by a factor (e.g., 5) for better visualization
    plt.scatter(df[wing].index, df[wing]['wifi'],
                s=df[wing]['wifi']*5,  # Scale by multiplying with a factor for better visibility
                label=f'Wi-Fi - Wing {wing.upper()}',
                alpha=0.6, edgecolors="w")  # Adding a white edge to make bubbles clearer

# Adding titles and labels
plt.title('Bubble Chart: Wi-Fi Signal Strength vs Measurement Number Across Wings', fontsize=16)
plt.xlabel('Measurement Number', fontsize=14)
plt.ylabel('Wi-Fi Signal Strength (dBm)', fontsize=14)

# Display the legend and adjust the layout
plt.legend(loc='best', fontsize=10)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt

# Set up the figure for the bubble chart
plt.figure(figsize=(12, 6))
# Load Level 4 data
df = load_wing_data("L4")
# Loop through each wing to create a scatter plot for each Wi-Fi signal strength
for wing in df:
    # Bubble size is proportional to the Wi-Fi signal strength
    # Scale the size of the bubbles by multiplying by a factor (e.g., 5) for better visualization
    plt.scatter(df[wing].index, df[wing]['wifi'],
                s=df[wing]['wifi']*5,  # Scale by multiplying with a factor for better visibility
                label=f'Wi-Fi - Wing {wing.upper()}',
                alpha=0.6, edgecolors="w")  # Adding a white edge to make bubbles clearer

# Adding titles and labels
plt.title('Bubble Chart: Wi-Fi Signal Strength vs Measurement Number Across Wings', fontsize=16)
plt.xlabel('Measurement Number', fontsize=14)
plt.ylabel('Wi-Fi Signal Strength (dBm)', fontsize=14)

# Display the legend and adjust the layout
plt.legend(loc='best', fontsize=10)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Cumulative Distribution Function (CDF) for Wi-Fi Signal Strengths
plt.figure(figsize=(12, 6))
# Load Level 3 data
df = load_wing_data("L3")
# Plot the CDF for Wi-Fi signal strength for each wing
for wing in df:
    sns.ecdfplot(df[wing]['wifi'], label=f'Wi-Fi - Wing {wing.upper()}')

plt.title('Cumulative Distribution Function of Wi-Fi Signal Strengths Across Wings')
plt.xlabel('Signal Strength')
plt.ylabel('CDF')
plt.legend(loc='best', fontsize=10)
plt.tight_layout()
plt.show()

# Cumulative Distribution Function (CDF) for Mobile Network Signal Strengths
plt.figure(figsize=(12, 6))

# Plot the CDF for Mobile Network signal strength for each wing
for wing in df:
    sns.ecdfplot(df[wing]['mobile_net'], label=f'Mobile Network - Wing {wing.upper()}')

plt.title('Cumulative Distribution Function of Mobile Network Signal Strengths Across Wings')
plt.xlabel('Signal Strength')
plt.ylabel('CDF')
plt.legend(loc='best', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Cumulative Distribution Function (CDF) for Wi-Fi Signal Strengths
plt.figure(figsize=(12, 6))
# Load Level 4 data
df = load_wing_data("L4")
# Plot the CDF for Wi-Fi signal strength for each wing
for wing in df:
    sns.ecdfplot(df[wing]['wifi'], label=f'Wi-Fi - Wing {wing.upper()}')

plt.title('Cumulative Distribution Function of Wi-Fi Signal Strengths Across Wings')
plt.xlabel('Signal Strength')
plt.ylabel('CDF')
plt.legend(loc='best', fontsize=10)
plt.tight_layout()
plt.show()

# Cumulative Distribution Function (CDF) for Mobile Network Signal Strengths
plt.figure(figsize=(12, 6))

# Plot the CDF for Mobile Network signal strength for each wing
for wing in df:
    sns.ecdfplot(df[wing]['mobile_net'], label=f'Mobile Network - Wing {wing.upper()}')

plt.title('Cumulative Distribution Function of Mobile Network Signal Strengths Across Wings')
plt.xlabel('Signal Strength')
plt.ylabel('CDF')
plt.legend(loc='best', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
print(len(df[wing]['wifi']))  # Check how many data points you have

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Example: Assume you have 2D grid data for each wing's Wi-Fi signal strength.
# Here, I will simulate a 2D grid for Wi-Fi signal strength.
# You need to adjust this part to work with your actual data.
# Let's assume you have the 'wifi' data for each wing and want to plot contours

plt.figure(figsize=(12, 6))

# Loop through each wing to plot contour maps
for wing in df:
    # Create a 2D grid for the x and y axis
    x = np.linspace(0, len(df[wing]), len(df[wing]))  # Adjust this based on your data's x-axis
    y = np.linspace(0, len(df[wing]['wifi']), len(df[wing]['wifi']))  # Adjust this based on your data

    # Generate meshgrid
    X, Y = np.meshgrid(x, y)

    # Get the Wi-Fi signal strength values (you might need to reshape or interpolate data)
    Z = np.array(df[wing]['wifi']).reshape(len(y), len(x))  # This assumes you can reshape your data into a 2D grid.

    # Plot contours using filled contours for better visualization
    contour = plt.contourf(X, Y, Z, cmap='coolwarm', levels=15)  # Adjust levels as needed for better clarity
    plt.colorbar(contour)  # Colorbar to show the scale of Wi-Fi signal strength

    # Adding title and labels
    plt.title(f'Contour Plot of Wi-Fi Signal Strength - Wing {wing.upper()}', fontsize=16)
    plt.xlabel('Measurement Point (X)')
    plt.ylabel('Measurement Point (Y)')

    plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-18d7af94c766> in <cell line: 0>()
#      20
#      21     # Get the Wi-Fi signal strength values (you might need to reshape or interpolate data)
# ---> 22     Z = np.array(df[wing]['wifi']).reshape(len(y), len(x))  # This assumes you can reshape your data into a 2D grid.
#      23
#      24     # Plot contours using filled contours for better visualization
#
# ValueError: cannot reshape array of size 5 into shape (5,5)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate

# Generate a grid for the contour plot
# Assuming you're using the indices for X and Y, and Wi-Fi values for Z
# Load Level 3 data
df = load_wing_data("L3")
# Create a list to store the coordinates and Wi-Fi values
coordinates = []
wifi_values = []

# Collect the data for all wings
for wing in df:
    x = np.arange(len(df[wing]))  # Measurement points (x-axis)
    y = np.random.normal(0, 0.1, len(x))  # Add small random noise to break flatness
    wifi_data = df[wing]['wifi']

    # Append the data
    coordinates.extend(zip(x, y))
    wifi_values.extend(wifi_data)

# Convert to numpy arrays
coordinates = np.array(coordinates)
wifi_values = np.array(wifi_values)

# Interpolate data into a 2D grid
grid_x, grid_y = np.meshgrid(np.linspace(coordinates[:, 0].min(), coordinates[:, 0].max(), 100),
                             np.linspace(coordinates[:, 1].min(), coordinates[:, 1].max(), 100))

# Perform griddata interpolation to get Z (Wi-Fi signal strength) values on the grid
grid_z = scipy.interpolate.griddata(coordinates, wifi_values, (grid_x, grid_y), method='cubic')

# Create the plot
plt.figure(figsize=(12, 6))

# Scatter plot of the data points (Wi-Fi signal strength)
for wing in df:
    x = np.arange(len(df[wing]))  # Measurement indices as x
    y = np.random.normal(0, 0.1, len(x))  # Add small random noise to break flatness
    plt.scatter(x, y, c=df[wing]['wifi'], cmap='coolwarm', edgecolors='black', label=f'Wi-Fi - Wing {wing.upper()}')

# Plot contours
plt.contour(grid_x, grid_y, grid_z, levels=15, cmap='coolwarm', alpha=0.5)

plt.title(f'Contour Plot of Wi-Fi Signal Strength')
plt.xlabel('wings')
plt.ylabel('locations')
plt.colorbar(label='Wi-Fi Signal Strength')
plt.legend(loc='best')
plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L3/L3_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L3/L3_h_signal_strength.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate

# Generate a grid for the contour plot
# Assuming you're using the indices for X and Y, and Wi-Fi values for Z
# Load Level 4 data
df = load_wing_data("L4")
# Create a list to store the coordinates and Wi-Fi values
coordinates = []
wifi_values = []

# Collect the data for all wings
for wing in df:
    x = np.arange(len(df[wing]))  # Measurement points (x-axis)
    y = np.random.normal(0, 0.1, len(x))  # Add small random noise to break flatness
    wifi_data = df[wing]['wifi']

    # Append the data
    coordinates.extend(zip(x, y))
    wifi_values.extend(wifi_data)

# Convert to numpy arrays
coordinates = np.array(coordinates)
wifi_values = np.array(wifi_values)

# Interpolate data into a 2D grid
grid_x, grid_y = np.meshgrid(np.linspace(coordinates[:, 0].min(), coordinates[:, 0].max(), 100),
                             np.linspace(coordinates[:, 1].min(), coordinates[:, 1].max(), 100))

# Perform griddata interpolation to get Z (Wi-Fi signal strength) values on the grid
grid_z = scipy.interpolate.griddata(coordinates, wifi_values, (grid_x, grid_y), method='cubic')

# Create the plot
plt.figure(figsize=(12, 6))

# Scatter plot of the data points (Wi-Fi signal strength)
for wing in df:
    x = np.arange(len(df[wing]))  # Measurement indices as x
    y = np.random.normal(0, 0.1, len(x))  # Add small random noise to break flatness
    plt.scatter(x, y, c=df[wing]['wifi'], cmap='coolwarm', edgecolors='black', label=f'Wi-Fi - Wing {wing.upper()}')

# Plot contours
plt.contour(grid_x, grid_y, grid_z, levels=15, cmap='coolwarm', alpha=0.5)

plt.title(f'Contour Plot of Wi-Fi Signal Strength')
plt.xlabel('wings')
plt.ylabel('locations')
plt.colorbar(label='Wi-Fi Signal Strength')
plt.legend(loc='best')
plt.tight_layout()
plt.show()
# Out:
# 📂 Loaded: /content/Dataset/L4/L4_a_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_b_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_c_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_d_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_e_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_f_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_g_signal_strength.csv
# 📂 Loaded: /content/Dataset/L4/L4_h_signal_strength.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate

# Generate a grid for the contour plot
# Assuming you're using the indices for X and Y, and Wi-Fi values for Z

# Create a list to store the coordinates and Wi-Fi values
coordinates = []
wifi_values = []

# Collect the data for all wings
for wing in df:
    x = np.arange(len(df[wing]))  # Measurement points (x-axis)
    y = np.random.normal(0, 0.1, len(x))  # Add small random noise to break flatness
    wifi_data = df[wing]['wifi']

    # Append the data
    coordinates.extend(zip(x, y))
    wifi_values.extend(wifi_data)

# Convert to numpy arrays
coordinates = np.array(coordinates)
wifi_values = np.array(wifi_values)

# Interpolate data into a 2D grid
grid_x, grid_y = np.meshgrid(np.linspace(coordinates[:, 0].min(), coordinates[:, 0].max(), 200),
                             np.linspace(coordinates[:, 1].min(), coordinates[:, 1].max(), 200))

# Perform griddata interpolation to get Z (Wi-Fi signal strength) values on the grid
grid_z = scipy.interpolate.griddata(coordinates, wifi_values, (grid_x, grid_y), method='cubic')

# Create the plot
plt.figure(figsize=(14, 8))

# Scatter plot of the data points (Wi-Fi signal strength)
for wing in df:
    x = np.arange(len(df[wing]))  # Measurement indices as x
    y = np.random.normal(0, 0.1, len(x))  # Add small random noise to break flatness
    plt.scatter(x, y, c=df[wing]['wifi'], cmap='coolwarm', edgecolors='black', s=50, alpha=0.6, label=f'Wi-Fi - Wing {wing.upper()}')

# Plot contours with more levels for a smoother gradient
contours = plt.contour(grid_x, grid_y, grid_z, levels=30, cmap='coolwarm', alpha=0.6)

# Add contour labels to each contour for better readability
plt.clabel(contours, inline=True, fontsize=8, fmt="%.2f")

# Title and labels
plt.title('Contour Plot of Wi-Fi Signal Strength Across Measurement Points', fontsize=16)
plt.xlabel('Measurement Point X', fontsize=12)
plt.ylabel('Measurement Point Y', fontsize=12)

# Add a colorbar
plt.colorbar(label='Wi-Fi Signal Strength')

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Improve the legend
plt.legend(loc='best', fontsize=10, title="Wi-Fi Wings", title_fontsize=12)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
df
# Out:
# {'a':          wifi  mobile_net
#  Point 1    80         120
#  Point 2    76         109
#  Point 3    61         103
#  Point 4    48         123
#  Point 5    62         119,
#  'b':          wifi  mobile_net
#  Point 1    89         115
#  Point 2    62         117
#  Point 3    50         128
#  Point 4    73         126
#  Point 5    82         123
#  Point 6    58         131
#  Point 7    61         131,
#  'c':          wifi  mobile_net
#  Point 1    89         103
#  Point 2    91         101
#  Point 3    93         115
#  Point 4   114         111
#  Point 5    72         103
#  Point 6    80         107,
#  'd':          wifi  mobile_net
#  Point 1    85          99
#  Point 2    89          97
#  Point 3    91         105
#  Point 4   100         118
#  Point 5    81         109
#  Point 6    74         104,
#  'e':           wifi  mobile_net
#  Point 1     73         105
#  Point 2     46         104
#  Point 3     75         102
#  Point 4     66         111
# ...
